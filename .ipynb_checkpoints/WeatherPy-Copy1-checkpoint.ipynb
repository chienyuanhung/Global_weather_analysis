# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 611

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# base url for api
url = "http://api.openweathermap.org/data/2.5/weather?"

# list for creating dataframe
weather_data= []
# count the usable results
i = 1
j = 1
# get weather informatiom for each city

# print the information for retriveing the data

print('Beginning Data Retrieval')
print('-----------------------------')

for city in cities: 
    weather_url =  f"{url}appid={api_key}&q={city}&units=imperial"
    city_weather = requests.get(weather_url).json()
    try:
        print(f"processing record: {i}, {city_weather['name']}, city id: {city_weather['id']}")
        if i <=50:
            i += 1 
             
        weather_data.append(city_weather)         
    except:
        print('City not found. Skipping...')

print('-----------------------------')
print('Data Retrieval Complete')
print('-----------------------------')
# Out:
# Beginning Data Retrieval
# -----------------------------
# processing record: 1, Avera, 4231997
# processing record: 2, Wattegama, 1241622
# processing record: 3, Georgetown, 3378644
# processing record: 4, Gizo, 6693679
# processing record: 5, Jalu, 86049
# processing record: 6, Albany, 5106834
# processing record: 7, Fort Nelson, 5955902
# City not found. Skipping...
# processing record: 8, Uvira, 204405
# processing record: 9, Leander, 4705708
# processing record: 10, Punta Arenas, 3874787
# processing record: 11, Arraial do Cabo, 3471451
# processing record: 12, Rikitea, 4030556
# processing record: 13, Talnakh, 1490256
# processing record: 14, Chepareria, 199604
# processing record: 15, Huarmey, 3939168
# processing record: 16, New Norfolk, 2155415
# processing record: 17, Nakhon Thai, 1608524
# City not found. Skipping...
# processing record: 18, Upernavik, 3418910
# processing record: 19, Saint-Francois, 2980080
# processing record: 20, Ushuaia, 3833367
# processing record: 21, Victoria, 1733782
# processing record: 22, Gazojak, 1514792
# processing record: 23, Mataura, 6201424
# processing record: 24, Altay, 1529651
# processing record: 25, Vaini, 1273574
# processing record: 26, Springbok, 3361142
# processing record: 27, Camargo, 4013724
# processing record: 28, Hermanus, 3366880
# processing record: 29, Bethel, 5880568
# processing record: 30, Castro-Urdiales, 3125621
# processing record: 31, Bluff, 2175403
# processing record: 32, Atuona, 4020109
# processing record: 33, Taoudenni, 2450173
# processing record: 34, Dabola, 2422442
# processing record: 35, Cape Town, 3369157
# processing record: 36, Barrow, 3833859
# processing record: 37, Puerto Ayora, 3652764
# processing record: 38, Uyuni, 3901903
# City not found. Skipping...
# processing record: 39, Qaanaaq, 3831208
# processing record: 40, Bakchar, 1511057
# processing record: 41, Tuktoyaktuk, 6170031
# processing record: 42, Port Alfred, 964432
# processing record: 43, Berlevag, 780687
# processing record: 44, Busselton, 2075265
# processing record: 45, Viedma, 3832899
# processing record: 46, East London, 1006984
# processing record: 47, Worthington, 5053460
# City not found. Skipping...
# processing record: 48, Kavieng, 2094342
# processing record: 49, Tiksi, 2015306
# processing record: 50, Longyearbyen, 2729907
# processing record: 51, Talaya, 1485724
# processing record: 52, Mar del Plata, 3863379
# processing record: 53, Fort Thomas, 4292071
# processing record: 54, Khatanga, 2022572
# processing record: 55, Norman Wells, 6089245
# processing record: 56, Arlit, 2447513
# processing record: 57, Bud, 7626370
# processing record: 58, Avarua, 4035715
# City not found. Skipping...
# processing record: 59, Nikolskoye, 546105
# processing record: 60, Nabire, 1634614
# processing record: 61, Makakilo City, 5850554
# processing record: 62, Butaritari, 2110227
# processing record: 63, Kaitangata, 2208248
# processing record: 64, Norsup, 2135517
# processing record: 65, Paita, 3694112
# processing record: 66, Hilo, 5855927
# processing record: 67, Esperance, 3573739
# processing record: 68, Airai, 1651810
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# create list for weather data DataFrame

city_name = [city['name'] for city in weather_data]
cloudiness = [city['clouds']['all'] for city in weather_data]
country = [city['sys']['country'] for city in weather_data]
date = [city['dt'] for city in weather_data]
humidity = [city['main']['humidity'] for city in weather_data]
lat = [city['coord']['lat'] for city in weather_data]
lng = [city['coord']['lon'] for city in weather_data]
max_temp = [city['main']['temp_max'] for city in weather_data]
wind_speed = [city['wind']['speed'] for city in weather_data]


# create the Dataframe for city weather
city_weather_data = {'City' : city_name, 'Cloudiness' : cloudiness, 'Country' : country, 'Date' : date, 'Humidity' : humidity,
          'Lat' : lat, 'Lng' : lng, 'Max Temp': max_temp, 'Wind Speed' : wind_speed }

city_weather_data = pd.DataFrame(city_weather_data)
city_weather_data.to_csv("../analysis_results/city_weather_data_2.csv")
city_weather_data.dtypes
# Out:
# City           object
# Cloudiness      int64
# Country        object
# Date            int64
# Humidity        int64
# Lat           float64
# Lng           float64
# Max Temp      float64
# Wind Speed    float64
# dtype: object

# %%
city_weather_data.head()
# Out:
#          City  Cloudiness Country        Date  Humidity    Lat    Lng  \
# 0       Avera           1      US  1558723116        46  33.19 -82.53
# 1   Wattegama         100      LK  1558723116        85   7.35  80.68
# 2  Georgetown          75      GY  1558723071        94   6.80 -58.16
# 3        Gizo           0      IL  1558723117        73  31.80  34.94
# 4        Jalu           0      LY  1558723117        17  29.03  21.55
#
#    Max Temp  Wind Speed
# 0     93.99        8.05
# 1     75.90        4.05
# 2     77.00        2.24
# 3     80.01        9.17
# 4     84.72       11.18

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# find the date for current data
from datetime import datetime

#get weather data from the stored csv file
city_weather_data = pd.read_csv('../analysis_results/city_weather_data_2.csv')

city_timestamp = city_weather_data['Date'][0]
city_dt = datetime.fromtimestamp(city_timestamp)
city_year = city_dt.strftime("%Y")
city_month = city_dt.strftime("%m")
city_day = city_dt.strftime("%d")
#formating date on the plot
weather_date = f"{city_month}/{city_day }/{city_year}"

#formating date for storing plot
weather_date_2 = f"{city_month}_{city_day }_{city_year}"

# %%
# scatter plot: Lat vs Max Temp
plt.scatter(city_weather_data['Lat'], city_weather_data['Max Temp'], marker = 'o', color = 'cyan', edgecolors = 'black')

# formating the plot
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title(f'City Latitude vs.Max Temperature ({weather_date})_2')
plt.grid()

#storing the picture
plt.savefig(f'City_Latitude_vs_Max_Temperature_{weather_date_2}_.png')

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(city_weather_data['Lat'], city_weather_data['Humidity'], marker = 'o', color = 'cyan', edgecolors = 'black')

# formating the plot
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title(f'City Latitude vs.Humidity ({weather_date})')
plt.grid()

#storing the picture
plt.savefig(f'City_Latitude_vs_Humidity_{weather_date_2}_2.png')

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(city_weather_data['Lat'], city_weather_data['Cloudiness'], marker = 'o', color = 'cyan', edgecolors = 'black')

# formating the plot
plt.xlabel('Latitude')
plt.ylabel('cloudiness(%)')
plt.title(f'City Latitude vs.Cloudiness ({weather_date})')
plt.grid()

#storing the picture
plt.savefig(f'City_Latitude_vs_Cloudiness_{weather_date_2}_2.png')

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(city_weather_data['Lat'], city_weather_data['Wind Speed'], marker = 'o', color = 'cyan', edgecolors = 'black')

# formating the plot
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title(f'City Latitude vs.Wind Speed ({weather_date})')
plt.grid()

#storing the picture
plt.savefig(f'City_Latitude_vs_Wind_Speed_{weather_date_2}_2.png')
